# %% [markdown]
# # Convert EBM to IRM
#
# This notebook takes the three-layer energy balance model tunings from Donald Cummins and converts them to a three-layer impulse response function.
#
# It will then save these into a CSV file.

# %%
import os

import numpy as np
import pandas as pd
import scipy.linalg
from tqdm import tqdm

from fair21.constants.general import (
    EARTH_RADIUS,
    SECONDS_PER_YEAR,
    DOUBLING_TIME_1PCT
)

# %%
df = pd.read_csv(
    os.path.join("..", "data", "calibration", "4xCO2_cummins.csv")
)

# %%
models = df['model'].unique()
models
# Out:
# array(['ACCESS-CM2', 'ACCESS-ESM1-5', 'AWI-CM-1-1-MR', 'BCC-CSM2-MR',
#        'BCC-ESM1', 'CAMS-CSM1-0', 'CESM2-FV2', 'CESM2-WACCM',
#        'CESM2-WACCM-FV2', 'CMCC-CM2-SR5', 'CNRM-CM6-1', 'CNRM-CM6-1-HR',
#        'CNRM-ESM2-1', 'CanESM5', 'E3SM-1-0', 'FGOALS-g3', 'GISS-E2-1-G',
#        'GISS-E2-1-H', 'GISS-E2-2-G', 'HadGEM3-GC31-LL', 'HadGEM3-GC31-MM',
#        'MIROC-ES2L', 'MIROC6', 'MPI-ESM1-2-HR', 'MPI-ESM1-2-LR',
#        'MRI-ESM2-0', 'NorCPM1', 'SAM0-UNICON'], dtype=object)

# %%
params = {}
for model in models:
    params[model] = {}
    for run in df.loc[df['model']==model, 'run']:
        condition = (df['model']==model) & (df['run']==run)
        params[model][run] = {}
        params[model][run]['gamma_autocorrelation'] = df.loc[condition, 'gamma'].values[0]
        params[model][run]['ocean_heat_capacity'] = df.loc[condition, 'C1':'C3'].values.squeeze()
        params[model][run]['ocean_heat_transfer'] = df.loc[condition, 'kappa1':'kappa3'].values.squeeze()
        params[model][run]['deep_ocean_efficacy'] = df.loc[condition, 'epsilon'].values[0]
        params[model][run]['sigma_eta'] = df.loc[condition, 'sigma_eta'].values[0]
        params[model][run]['sigma_xi'] = df.loc[condition, 'sigma_xi'].values[0]
        params[model][run]['forcing_4co2'] = df.loc[condition, 'F_4xCO2'].values[0]

# %%
params
# Out:
# {'ACCESS-CM2': {'r1i1p1f1': {'gamma_autocorrelation': 1.88578590071159,
#    'ocean_heat_capacity': array([ 3.67420401, 10.0509273 , 79.00113427]),
#    'ocean_heat_transfer': array([0.70452914, 3.78694388, 0.69714927]),
#    'deep_ocean_efficacy': 1.43982936529305,
#    'sigma_eta': 0.457682866431186,
#    'sigma_xi': 0.562736202801604,
#    'forcing_4co2': 7.57713207902355}},
#  'ACCESS-ESM1-5': {'r1i1p1f1': {'gamma_autocorrelation': 2.536269864266,
#    'ocean_heat_capacity': array([ 3.61230801, 10.36738403, 83.22149704]),
#    'ocean_heat_transfer': array([0.66715386, 2.73896097, 0.92627042]),
#    'deep_ocean_efficacy': 1.51117641602166,
#    'sigma_eta': 0.628051953981854,
#    'sigma_xi': 0.545553625801671,
#    'forcing_4co2': 6.27462871581454}},
#  'AWI-CM-1-1-MR': {'r1i1p1f1': {'gamma_autocorrelation': 4.3311591350037,
#    'ocean_heat_capacity': array([ 4.22019861,  9.60696442, 47.65990971]),
#    'ocean_heat_transfer': array([1.18366473, 1.99569026, 0.71614617]),
#    'deep_ocean_efficacy': 1.39857899287456,
#    'sigma_eta': 0.968857971626109,
#    'sigma_xi': 0.683844740600272,
#    'forcing_4co2': 7.92007525512892}},
#  'BCC-CSM2-MR': {'r1i1p1f1': {'gamma_autocorrelation': 1.07006338574359,
#    'ocean_heat_capacity': array([ 4.19997307, 13.61348231, 61.89703597]),
#    'ocean_heat_transfer': array([1.20335257, 2.43874534, 1.00025477]),
#    'deep_ocean_efficacy': 1.76098952427176,
#    'sigma_eta': 0.450354326659591,
#    'sigma_xi': 0.359787402987183,
#    'forcing_4co2': 8.00980195711205}},
#  'BCC-ESM1': {'r1i1p1f1': {'gamma_autocorrelation': 1.7741776717623,
#    'ocean_heat_capacity': array([ 5.23546862, 19.67200248, 84.60713577]),
#    'ocean_heat_transfer': array([0.81870014, 1.29809929, 0.73917536]),
#    'deep_ocean_efficacy': 1.1726361819138,
#    'sigma_eta': 0.38779776543499,
#    'sigma_xi': 0.308130864471242,
#    'forcing_4co2': 5.76721177147012}},
#  'CAMS-CSM1-0': {'r1i1p1f1': {'gamma_autocorrelation': 26.1842638850912,
#    'ocean_heat_capacity': array([ 3.03080981,  9.5184772 , 54.032154  ]),
#    'ocean_heat_transfer': array([1.87922273, 4.67983415, 0.62522687]),
#    'deep_ocean_efficacy': 1.23381413761814,
#    'sigma_eta': 2.61422336152937,
#    'sigma_xi': 0.469949750754825,
#    'forcing_4co2': 8.81726976716197},
#   'r2i1p1f1': {'gamma_autocorrelation': 4.45369695797436,
#    'ocean_heat_capacity': array([ 5.16639424,  8.33018482, 52.74275267]),
#    'ocean_heat_transfer': array([1.87486115, 2.84281625, 0.71386904]),
#    'deep_ocean_efficacy': 1.19147403839583,
#    'sigma_eta': 1.01554441520222,
#    'sigma_xi': 0.664353128066589,
#    'forcing_4co2': 8.76392408979086}},
#  'CESM2-FV2': {'r1i1p1f1': {'gamma_autocorrelation': 2.78532613466765,
#    'ocean_heat_capacity': array([ 3.73086879,  6.59462335, 88.00397829]),
#    'ocean_heat_transfer': array([0.55707466, 4.02828954, 0.99821131]),
#    'deep_ocean_efficacy': 1.74225443031892,
#    'sigma_eta': 0.884084964805016,
#    'sigma_xi': 0.596270345261132,
#    'forcing_4co2': 7.45032463046688}},
#  'CESM2-WACCM': {'r1i1p1f1': {'gamma_autocorrelation': 2.7094748138317,
#    'ocean_heat_capacity': array([ 3.86789217,  6.08948598, 87.38025452]),
#    'ocean_heat_transfer': array([0.71584383, 6.74172126, 0.81784833]),
#    'deep_ocean_efficacy': 1.54854552009904,
#    'sigma_eta': 0.680289021595491,
#    'sigma_xi': 0.50060414011186,
#    'forcing_4co2': 7.93905729802643}},
#  'CESM2-WACCM-FV2': {'r1i1p1f1': {'gamma_autocorrelation': 2.86472926458094,
#    'ocean_heat_capacity': array([  3.45076663,   9.25233856, 108.07195884]),
#    'ocean_heat_transfer': array([0.56326322, 3.6508851 , 0.90875837]),
#    'deep_ocean_efficacy': 1.44636751890696,
#    'sigma_eta': 0.941652290398963,
#    'sigma_xi': 0.550065316162513,
#    'forcing_4co2': 6.61641893651646}},
#  'CMCC-CM2-SR5': {'r1i1p1f1': {'gamma_autocorrelation': 25.0581596639922,
#    'ocean_heat_capacity': array([  4.30519893,  18.02464644, 292.18020205]),
#    'ocean_heat_transfer': array([1.43160004, 1.21948997, 0.26868387]),
#    'deep_ocean_efficacy': 0.0060914765310334,
#    'sigma_eta': 2.47139925787306,
#    'sigma_xi': 0.902336635367978,
#    'forcing_4co2': 8.31628049989487}},
#  'CNRM-CM6-1': {'r1i1p1f2': {'gamma_autocorrelation': 4.80772174825144,
#    'ocean_heat_capacity': array([  5.27609092,  15.66758907, 195.18322781]),
#    'ocean_heat_transfer': array([1.27034132, 1.14532389, 0.4119936 ]),
#    'deep_ocean_efficacy': 0.0429595651077335,
#    'sigma_eta': 0.692177568083074,
#    'sigma_xi': 0.702132491057823,
#    'forcing_4co2': 8.60195313357141}},
#  'CNRM-CM6-1-HR': {'r1i1p1f2': {'gamma_autocorrelation': 3.50874892560624,
#    'ocean_heat_capacity': array([  5.4691211 ,  13.25120584, 105.88971749]),
#    'ocean_heat_transfer': array([1.11016086, 1.61573987, 0.54283182]),
#    'deep_ocean_efficacy': 0.565725333756195,
#    'sigma_eta': 0.513096067735878,
#    'sigma_xi': 0.592525735216935,
#    'forcing_4co2': 8.24627266370149}},
#  'CNRM-ESM2-1': {'r1i1p1f2': {'gamma_autocorrelation': 3.78362020552353,
#    'ocean_heat_capacity': array([  4.07131447,   6.98021824, 100.23643641]),
#    'ocean_heat_transfer': array([0.63448381, 2.65123022, 0.69380362]),
#    'deep_ocean_efficacy': 0.825997165041863,
#    'sigma_eta': 0.843202540602261,
#    'sigma_xi': 0.568204265865447,
#    'forcing_4co2': 5.63966830787197},
#   'r3i1p1f2': {'gamma_autocorrelation': 26.2980281166536,
#    'ocean_heat_capacity': array([ 3.48859882,  6.38490241, 99.43651901]),
#    'ocean_heat_transfer': array([0.66615671, 3.57971215, 0.69781821]),
#    'deep_ocean_efficacy': 0.896742725230145,
#    'sigma_eta': 1.91569944816319,
#    'sigma_xi': 0.574054090448029,
#    'forcing_4co2': 5.95757435174292}},
#  'CanESM5': {'r1i1p1f1': {'gamma_autocorrelation': 2.82305865552295,
#    'ocean_heat_capacity': array([ 3.77880871,  9.79628881, 75.96860557]),
#    'ocean_heat_transfer': array([0.61304959, 2.07928869, 0.6179695 ]),
#    'deep_ocean_efficacy': 0.93519958532787,
#    'sigma_eta': 0.572201380172173,
#    'sigma_xi': 0.479149398549552,
#    'forcing_4co2': 6.92177501762997},
#   'r1i1p2f1': {'gamma_autocorrelation': 2.51143941345753,
#    'ocean_heat_capacity': array([ 3.60889269, 10.88432547, 70.14913088]),
#    'ocean_heat_transfer': array([0.62758713, 2.45486017, 0.62008856]),
#    'deep_ocean_efficacy': 1.15776538302692,
#    'sigma_eta': 0.417481876691909,
#    'sigma_xi': 0.479755267878344,
#    'forcing_4co2': 7.47074196548227}},
#  'E3SM-1-0': {'r1i1p1f1': {'gamma_autocorrelation': 3.14318525791325,
#    'ocean_heat_capacity': array([ 3.67833854,  9.6262782 , 42.42703496]),
#    'ocean_heat_transfer': array([0.58086435, 2.37986856, 0.37426844]),
#    'deep_ocean_efficacy': 1.57356578948367,
#    'sigma_eta': 0.918048348765317,
#    'sigma_xi': 0.614842838459725,
#    'forcing_4co2': 7.11344278255743}},
#  'FGOALS-g3': {'r1i1p1f1': {'gamma_autocorrelation': 1.07880964648931,
#    'ocean_heat_capacity': array([ 4.23178497,  8.1559701 , 90.57676616]),
#    'ocean_heat_transfer': array([1.26096056, 2.67171538, 1.00144013]),
#    'deep_ocean_efficacy': 1.27388897880196,
#    'sigma_eta': 0.23012580172404,
#    'sigma_xi': 0.449317674819603,
#    'forcing_4co2': 7.68519153799384}},
#  'GISS-E2-1-G': {'r102i1p1f1': {'gamma_autocorrelation': 2.25030209691627,
#    'ocean_heat_capacity': array([  3.2931074 ,  12.20439246, 161.32424595]),
#    'ocean_heat_transfer': array([1.8109177 , 2.26590861, 1.19340124]),
#    'deep_ocean_efficacy': 1.1145725437581,
#    'sigma_eta': 0.488319007970461,
#    'sigma_xi': 0.745975495529436,
#    'forcing_4co2': 9.47744120518306},
#   'r1i1p1f1': {'gamma_autocorrelation': 2.92056816960277,
#    'ocean_heat_capacity': array([  3.32765983,   8.98389571, 159.69494905]),
#    'ocean_heat_transfer': array([1.30302669, 1.85309552, 1.20375655]),
#    'deep_ocean_efficacy': 0.944535956018539,
#    'sigma_eta': 0.555859091152428,
#    'sigma_xi': 0.605959330369628,
#    'forcing_4co2': 7.17185409026478},
#   'r1i1p3f1': {'gamma_autocorrelation': 1.68295836230887,
#    'ocean_heat_capacity': array([  4.13673938,  12.09131653, 186.70910217]),
#    'ocean_heat_transfer': array([1.42433312, 2.60326461, 1.04810748]),
#    'deep_ocean_efficacy': 1.15466901552805,
#    'sigma_eta': 0.380869047103412,
#    'sigma_xi': 0.919417435308347,
#    'forcing_4co2': 7.76786235469861},
#   'r1i1p5f1': {'gamma_autocorrelation': 2.15403018477418,
#    'ocean_heat_capacity': array([  3.18326885,  12.89334008, 193.44857318]),
#    'ocean_heat_transfer': array([1.53283655, 1.79081889, 1.06567872]),
#    'deep_ocean_efficacy': 0.949730033755278,
#    'sigma_eta': 0.42370152660183,
#    'sigma_xi': 0.825314192983639,
#    'forcing_4co2': 7.97262147569649}},
#  'GISS-E2-1-H': {'r1i1p1f1': {'gamma_autocorrelation': 27.0171020207035,
#    'ocean_heat_capacity': array([ 2.24230388, 11.36871985, 73.22808348]),
#    'ocean_heat_transfer': array([1.02663741, 2.38772212, 0.83468411]),
#    'deep_ocean_efficacy': 0.973850127765011,
#    'sigma_eta': 1.97756475903138,
#    'sigma_xi': 0.491943107576315,
#    'forcing_4co2': 6.52056592577495},
#   'r1i1p3f1': {'gamma_autocorrelation': 2.67044817746255,
#    'ocean_heat_capacity': array([  4.32953767,  26.31392204, 327.46978074]),
#    'ocean_heat_transfer': array([1.52494394, 1.23402467, 0.32873857]),
#    'deep_ocean_efficacy': 0.206813262422408,
#    'sigma_eta': 0.478934994289842,
#    'sigma_xi': 0.777626225653503,
#    'forcing_4co2': 7.8546075751831}},
#  'GISS-E2-2-G': {'r1i1p1f1': {'gamma_autocorrelation': 2.18552097722105,
#    'ocean_heat_capacity': array([  4.02472762,  11.22278778, 261.33563114]),
#    'ocean_heat_transfer': array([2.22425355, 1.94523717, 0.58123096]),
#    'deep_ocean_efficacy': 0.16874299195582,
#    'sigma_eta': 0.546814136352882,
#    'sigma_xi': 0.599790795702886,
#    'forcing_4co2': 8.4727580078433}},
#  'HadGEM3-GC31-LL': {'r1i1p1f3': {'gamma_autocorrelation': 2.93774731293286,
#    'ocean_heat_capacity': array([ 3.82003306,  8.86062322, 66.05192503]),
#    'ocean_heat_transfer': array([0.63038091, 3.14919488, 0.64494935]),
#    'deep_ocean_efficacy': 1.21795095190017,
#    'sigma_eta': 0.446501649067072,
#    'sigma_xi': 0.617731091711553,
#    'forcing_4co2': 7.45443344404946}},
#  'HadGEM3-GC31-MM': {'r1i1p1f3': {'gamma_autocorrelation': 2.21436107149992,
#    'ocean_heat_capacity': array([ 3.91591825, 12.74101636, 64.44362675]),
#    'ocean_heat_transfer': array([0.68974294, 2.51101187, 0.67163127]),
#    'deep_ocean_efficacy': 1.10315315832446,
#    'sigma_eta': 0.451502567435,
#    'sigma_xi': 0.514735293089364,
#    'forcing_4co2': 7.58160948030469}},
#  'MIROC-ES2L': {'r1i1p1f2': {'gamma_autocorrelation': 1.77439764609673,
#    'ocean_heat_capacity': array([  4.31764089,  14.51652269, 391.50822672]),
#    'ocean_heat_transfer': array([2.15639625, 1.75738598, 0.58626557]),
#    'deep_ocean_efficacy': 0.195402759512074,
#    'sigma_eta': 0.683384554817314,
#    'sigma_xi': 0.910880418425589,
#    'forcing_4co2': 9.0982613450674}},
#  'MIROC6': {'r1i1p1f1': {'gamma_autocorrelation': 1.78006025608583,
#    'ocean_heat_capacity': array([  4.11067654,  30.05806814, 332.33341946]),
#    'ocean_heat_transfer': array([2.0315819 , 1.04725401, 0.53732622]),
#    'deep_ocean_efficacy': 0.263217073227109,
#    'sigma_eta': 0.700456280933403,
#    'sigma_xi': 0.851583705091037,
#    'forcing_4co2': 8.65392453995481}},
#  'MPI-ESM1-2-HR': {'r1i1p1f1': {'gamma_autocorrelation': 2.35461193110828,
#    'ocean_heat_capacity': array([ 5.34217409, 29.95208761, 62.29010106]),
#    'ocean_heat_transfer': array([1.11042939, 1.47648579, 1.08800609]),
#    'deep_ocean_efficacy': 1.6791176220264,
#    'sigma_eta': 0.506857585605866,
#    'sigma_xi': 0.446459734533372,
#    'forcing_4co2': 7.59191159157924}},
#  'MPI-ESM1-2-LR': {'r1i1p1f1': {'gamma_autocorrelation': 1.64327982352783,
#    'ocean_heat_capacity': array([  7.68504439,  40.37681842, 240.89746238]),
#    'ocean_heat_transfer': array([2.02620222, 0.8998633 , 0.30769474]),
#    'deep_ocean_efficacy': 0.188848227355158,
#    'sigma_eta': 0.43014058296196,
#    'sigma_xi': 0.986915849244127,
#    'forcing_4co2': 10.5957812291787}},
#  'MRI-ESM2-0': {'r10i1p1f1': {'gamma_autocorrelation': 1.83300475122777,
#    'ocean_heat_capacity': array([ 2.97900427,  9.14687929, 99.59691938]),
#    'ocean_heat_transfer': array([0.75189587, 2.27352058, 1.04085667]),
#    'deep_ocean_efficacy': 0.788418511825479,
#    'sigma_eta': 1.03559498975037,
#    'sigma_xi': 0.359860135094619,
#    'forcing_4co2': 4.9772796849414},
#   'r13i1p1f1': {'gamma_autocorrelation': 2.0134769887987,
#    'ocean_heat_capacity': array([ 2.99132354,  8.05696908, 99.88117652]),
#    'ocean_heat_transfer': array([0.74749683, 2.19011251, 0.99325308]),
#    'deep_ocean_efficacy': 0.634963826071758,
#    'sigma_eta': 1.3248530507852,
#    'sigma_xi': 0.248797560660394,
#    'forcing_4co2': 4.65587271277396},
#   'r1i1p1f1': {'gamma_autocorrelation': 3.58769129134887,
#    'ocean_heat_capacity': array([ 4.0236701 , 10.32077013, 94.06787447]),
#    'ocean_heat_transfer': array([1.04965949, 2.75348616, 1.20256025]),
#    'deep_ocean_efficacy': 1.26213544147637,
#    'sigma_eta': 1.05049333459864,
#    'sigma_xi': 0.486520129559173,
#    'forcing_4co2': 7.15917281695671},
#   'r1i2p1f1': {'gamma_autocorrelation': 1.6729977333648,
#    'ocean_heat_capacity': array([  5.13604304,  10.42982896, 105.80795014]),
#    'ocean_heat_transfer': array([1.34584232, 3.8043474 , 1.04338956]),
#    'deep_ocean_efficacy': 1.48316638311647,
#    'sigma_eta': 0.734783575964919,
#    'sigma_xi': 0.662928398856842,
#    'forcing_4co2': 8.86412397132535},
#   'r4i1p1f1': {'gamma_autocorrelation': 3.0651991680908,
#    'ocean_heat_capacity': array([ 4.34641373, 10.55814576, 97.27610378]),
#    'ocean_heat_transfer': array([0.97384105, 2.12528729, 1.19809847]),
#    'deep_ocean_efficacy': 1.05118214630619,
#    'sigma_eta': 0.88744156381239,
#    'sigma_xi': 0.523897529646629,
#    'forcing_4co2': 6.43696728048104},
#   'r7i1p1f1': {'gamma_autocorrelation': 2.01128445862497,
#    'ocean_heat_capacity': array([  3.23507448,  10.67735684, 100.00836551]),
#    'ocean_heat_transfer': array([0.8393753 , 2.26361674, 1.03056007]),
#    'deep_ocean_efficacy': 0.876485868887357,
#    'sigma_eta': 0.862150735637598,
#    'sigma_xi': 0.411838707423546,
#    'forcing_4co2': 5.53341963922204}},
#  'NorCPM1': {'r1i1p1f1': {'gamma_autocorrelation': 1.85111716233926,
#    'ocean_heat_capacity': array([ 6.50127123, 16.47901253, 91.37279523]),
#    'ocean_heat_transfer': array([1.13306878, 2.4141953 , 1.21382987]),
#    'deep_ocean_efficacy': 1.58424351521472,
#    'sigma_eta': 0.493369736136213,
#    'sigma_xi': 0.570571171701995,
#    'forcing_4co2': 7.79531063988835}},
#  'SAM0-UNICON': {'r1i1p1f1': {'gamma_autocorrelation': 2.37484031486553,
#    'ocean_heat_capacity': array([  4.58997223,   6.23947732, 109.80559208]),
#    'ocean_heat_transfer': array([1.03423517, 2.61922911, 1.02089967]),
#    'deep_ocean_efficacy': 1.23398288721619,
#    'sigma_eta': 0.797980779401583,
#    'sigma_xi': 0.635521988107223,
#    'forcing_4co2': 8.25615952011699}}}

# %%
# TODO: move to a constants module

forcing_2co2_4co2_ratio=0.476304  # TODO: un-hardcode this and calculate directly from Meinshausen or Etminan relations.

# %%
class EnergyBalanceModel:
    
    # Energy balance basics
    ocean_heat_capacity = np.array([5, 20, 100])
    ocean_heat_transfer = np.array([1, 2, 1])
    deep_ocean_efficacy = 1

    # Tuning
    forcing_4co2 = 8
    
    # Stochastic parameters (see Cummins et al. 2020)
    stochastic_run = False
    sigma_eta = 0.5
    sigma_xi = 0.5
    gamma_autocorrelation = 2

    # Output - not yet relevant
#    start = 1850.0
#    end = 2101.0
#    timestep = 0.2
#    outtime = None,
#    forcing = np.zeros(2)
    
    def __init__(self, **kwargs):
        self.ocean_heat_capacity = kwargs.get('ocean_heat_capacity', self.ocean_heat_capacity)
        self.ocean_heat_transfer = kwargs.get('ocean_heat_transfer', self.ocean_heat_transfer)
        self.deep_ocean_efficacy = kwargs.get('deep_ocean_efficacy', self.deep_ocean_efficacy)
        self.forcing_4co2 = kwargs.get('forcing_4co2', self.forcing_4co2)
        self.stochastic_run = kwargs.get('stochastic_run', self.stochastic_run)
        self.sigma_eta = kwargs.get('sigma_eta', self.sigma_eta)
        self.sigma_xi = kwargs.get('sigma_xi', self.sigma_xi)
        self.gamma_autocorrelation = kwargs.get('gamma_autocorrelation', self.gamma_autocorrelation)
    
    def _eb_matrix(self):
        # Define the matrix of differential equations
        # Cummins et al. (2020); Leach et al. (2021)
        eb_matrix = np.array(
            [
                [
                    -(self.ocean_heat_transfer[0]+self.ocean_heat_transfer[1])/self.ocean_heat_capacity[0],
                    self.ocean_heat_transfer[1]/self.ocean_heat_capacity[0], 
                    0
                ],
                [
                    self.ocean_heat_transfer[1]/self.ocean_heat_capacity[1],
                    -(self.ocean_heat_transfer[1]+self.deep_ocean_efficacy*self.ocean_heat_transfer[2])/self.ocean_heat_capacity[1],
                    self.deep_ocean_efficacy*self.ocean_heat_transfer[2]/self.ocean_heat_capacity[1]
                ],
                [
                    0, 
                    self.ocean_heat_transfer[2]/self.ocean_heat_capacity[2],
                    -self.ocean_heat_transfer[2]/self.ocean_heat_capacity[2]
                ]
            ]
        )
        return(eb_matrix)
    
        
    def impulse_response(self):
        eb_matrix = self._eb_matrix()

        # calculate the eigenvectors and eigenvalues, these are the timescales of responses
        eb_matrix_eigenvalues, eb_matrix_eigenvectors = scipy.linalg.eig(eb_matrix)
        self.timescales = -1/(np.real(eb_matrix_eigenvalues))
        self.response_coefficients = self.timescales * (eb_matrix_eigenvectors[0,:] * scipy.linalg.inv(eb_matrix_eigenvectors)[:,0]) / self.ocean_heat_capacity[0]

    def emergent_parameters(self):
        # requires impulse response step
        if not hasattr(self, 'timescales'):
            self.impulse_response()
        self.ecs = self.forcing_4co2 * forcing_2co2_4co2_ratio * np.sum(self.response_coefficients)
        self.tcr = self.forcing_4co2 * forcing_2co2_4co2_ratio * np.sum(
            self.response_coefficients*(
                1 - self.timescales/DOUBLING_TIME_1PCT * (
                    1 - np.exp(-DOUBLING_TIME_1PCT/self.timescales)
                )
            )
        )

# %%
ebm = EnergyBalanceModel(**params['ACCESS-CM2']['r1i1p1f1'])

# %%
ebm.emergent_parameters()

# %%
ebm.ecs
# Out:
# 5.122596220048067

# %%
for model in models:
    for run in df.loc[df['model']==model, 'run']:
        condition = (df['model']==model) & (df['run']==run)
        ebm = EnergyBalanceModel(**params[model][run])
        ebm.emergent_parameters()
        params[model][run] = ebm.__dict__

# %%
params
# Out:
# {'ACCESS-CM2': {'r1i1p1f1': {'ocean_heat_capacity': array([ 3.67420401, 10.0509273 , 79.00113427]),
#    'ocean_heat_transfer': array([0.70452914, 3.78694388, 0.69714927]),
#    'deep_ocean_efficacy': 1.43982936529305,
#    'forcing_4co2': 7.57713207902355,
#    'stochastic_run': False,
#    'sigma_eta': 0.457682866431186,
#    'sigma_xi': 0.562736202801604,
#    'gamma_autocorrelation': 1.88578590071159,
#    'timescales': array([  0.63456183,   7.75953934, 318.55119406]),
#    'response_coefficients': array([0.13065828, 0.494845  , 0.79388443]),
#    'ecs': 5.122596220048067,
#    'tcr': 2.3458843339066955}},
#  'ACCESS-ESM1-5': {'r1i1p1f1': {'ocean_heat_capacity': array([ 3.61230801, 10.36738403, 83.22149704]),
#    'ocean_heat_transfer': array([0.66715386, 2.73896097, 0.92627042]),
#    'deep_ocean_efficacy': 1.51117641602166,
#    'forcing_4co2': 6.27462871581454,
#    'stochastic_run': False,
#    'sigma_eta': 0.628051953981854,
#    'sigma_xi': 0.545553625801671,
#    'gamma_autocorrelation': 2.536269864266,
#    'timescales': array([  0.83679832,   6.43924083, 341.73100028]),
#    'response_coefficients': array([0.17580836, 0.41256469, 0.91053156]),
#    'ecs': 4.4796724470328,
#    'tcr': 1.897579528495123}},
#  'AWI-CM-1-1-MR': {'r1i1p1f1': {'ocean_heat_capacity': array([ 4.22019861,  9.60696442, 47.65990971]),
#    'ocean_heat_transfer': array([1.18366473, 1.99569026, 0.71614617]),
#    'deep_ocean_efficacy': 1.39857899287456,
#    'forcing_4co2': 7.92007525512892,
#    'stochastic_run': False,
#    'sigma_eta': 0.968857971626109,
#    'sigma_xi': 0.683844740600272,
#    'gamma_autocorrelation': 4.3311591350037,
#    'timescales': array([  1.09125869,   6.3306689 , 165.33753217]),
#    'response_coefficients': array([0.2034449 , 0.30705075, 0.33433817]),
#    'ecs': 3.187020288990703,
#    'tcr': 2.040491873565713}},
#  'BCC-CSM2-MR': {'r1i1p1f1': {'ocean_heat_capacity': array([ 4.19997307, 13.61348231, 61.89703597]),
#    'ocean_heat_transfer': array([1.20335257, 2.43874534, 1.00025477]),
#    'deep_ocean_efficacy': 1.76098952427176,
#    'forcing_4co2': 8.00980195711205,
#    'stochastic_run': False,
#    'sigma_eta': 0.450354326659591,
#    'sigma_xi': 0.359787402987183,
#    'gamma_autocorrelation': 1.07006338574359,
#    'timescales': array([  0.98534301,   5.80575406, 210.75095143]),
#    'response_coefficients': array([0.19386268, 0.2288215 , 0.40832746]),
#    'ecs': 3.170393127240652,
#    'tcr': 1.7606518110117526}},
#  'BCC-ESM1': {'r1i1p1f1': {'ocean_heat_capacity': array([ 5.23546862, 19.67200248, 84.60713577]),
#    'ocean_heat_transfer': array([0.81870014, 1.29809929, 0.73917536]),
#    'deep_ocean_efficacy': 1.1726361819138,
#    'forcing_4co2': 5.76721177147012,
#    'stochastic_run': False,
#    'sigma_eta': 0.38779776543499,
#    'sigma_xi': 0.308130864471242,
#    'gamma_autocorrelation': 1.7741776717623,
#    'timescales': array([  2.21115845,  14.72365884, 340.71813684]),
#    'response_coefficients': array([0.37024752, 0.32410933, 0.52709158]),
#    'ecs': 3.3552529251964995,
#    'tcr': 1.8269791296933}},
#  'CAMS-CSM1-0': {'r1i1p1f1': {'ocean_heat_capacity': array([ 3.03080981,  9.5184772 , 54.032154  ]),
#    'ocean_heat_transfer': array([1.87922273, 4.67983415, 0.62522687]),
#    'deep_ocean_efficacy': 1.23381413761814,
#    'forcing_4co2': 8.81726976716197,
#    'stochastic_run': False,
#    'sigma_eta': 2.61422336152937,
#    'sigma_xi': 0.469949750754825,
#    'gamma_autocorrelation': 26.1842638850912,
#    'timescales': array([  0.39239676,   5.18729385, 139.27264493]),
#    'response_coefficients': array([0.10838046, 0.27317551, 0.15057893]),
#    'ecs': 2.234807400317492,
#    'tcr': 1.649203669489331},
#   'r2i1p1f1': {'ocean_heat_capacity': array([ 5.16639424,  8.33018482, 52.74275267]),
#    'ocean_heat_transfer': array([1.87486115, 2.84281625, 0.71386904]),
#    'deep_ocean_efficacy': 1.19147403839583,
#    'forcing_4co2': 8.76392408979086,
#    'stochastic_run': False,
#    'sigma_eta': 1.01554441520222,
#    'sigma_xi': 0.664353128066589,
#    'gamma_autocorrelation': 4.45369695797436,
#    'timescales': array([  0.85362352,   5.23314662, 133.54857339]),
#    'response_coefficients': array([0.12187101, 0.25984655, 0.15165528]),
#    'ecs': 2.2264539936173544,
#    'tcr': 1.6454644884505816}},
#  'CESM2-FV2': {'r1i1p1f1': {'ocean_heat_capacity': array([ 3.73086879,  6.59462335, 88.00397829]),
#    'ocean_heat_transfer': array([0.55707466, 4.02828954, 0.99821131]),
#    'deep_ocean_efficacy': 1.74225443031892,
#    'forcing_4co2': 7.45032463046688,
#    'stochastic_run': False,
#    'sigma_eta': 0.884084964805016,
#    'sigma_xi': 0.596270345261132,
#    'gamma_autocorrelation': 2.78532613466765,
#    'timescales': array([  0.53088028,   4.36913354, 416.72906116]),
#    'response_coefficients': array([0.08622257, 0.44825003, 1.26061891]),
#    'ecs': 6.370096590325873,
#    'tcr': 2.148442971198568}},
#  'CESM2-WACCM': {'r1i1p1f1': {'ocean_heat_capacity': array([ 3.86789217,  6.08948598, 87.38025452]),
#    'ocean_heat_transfer': array([0.71584383, 6.74172126, 0.81784833]),
#    'deep_ocean_efficacy': 1.54854552009904,
#    'forcing_4co2': 7.93905729802643,
#    'stochastic_run': False,
#    'sigma_eta': 0.680289021595491,
#    'sigma_xi': 0.50060414011186,
#    'gamma_autocorrelation': 2.7094748138317,
#    'timescales': array([  0.32847515,   4.87631501, 325.54586242]),
#    'response_coefficients': array([0.05159692, 0.48180919, 0.86354664]),
#    'ecs': 5.282443759039323,
#    'tcr': 2.2142964837589605}},
#  'CESM2-WACCM-FV2': {'r1i1p1f1': {'ocean_heat_capacity': array([  3.45076663,   9.25233856, 108.07195884]),
#    'ocean_heat_transfer': array([0.56326322, 3.6508851 , 0.90875837]),
#    'deep_ocean_efficacy': 1.44636751890696,
#    'forcing_4co2': 6.61641893651646,
#    'stochastic_run': False,
#    'sigma_eta': 0.941652290398963,
#    'sigma_xi': 0.550065316162513,
#    'gamma_autocorrelation': 2.86472926458094,
#    'timescales': array([  0.62099443,   6.5030546 , 457.21139463]),
#    'response_coefficients': array([0.1320483 , 0.48524296, 1.15807764]),
#    'ecs': 5.594945138336581,
#    'tcr': 2.063313241122743}},
#  'CMCC-CM2-SR5': {'r1i1p1f1': {'ocean_heat_capacity': array([  4.30519893,  18.02464644, 292.18020205]),
#    'ocean_heat_transfer': array([1.43160004, 1.21948997, 0.26868387]),
#    'deep_ocean_efficacy': 0.0060914765310334,
#    'forcing_4co2': 8.31628049989487,
#    'stochastic_run': False,
#    'sigma_eta': 2.47139925787306,
#    'sigma_xi': 0.902336635367978,
#    'gamma_autocorrelation': 25.0581596639922,
#    'timescales': array([   1.54137365,   28.76371042, 1090.22565669]),
#    'response_coefficients': array([0.3387933 , 0.35888308, 0.00084275]),
#    'ecs': 2.7668884875245663,
#    'tcr': 2.1990807159750805}},
#  'CNRM-CM6-1': {'r1i1p1f2': {'ocean_heat_capacity': array([  5.27609092,  15.66758907, 195.18322781]),
#    'ocean_heat_transfer': array([1.27034132, 1.14532389, 0.4119936 ]),
#    'deep_ocean_efficacy': 0.0429595651077335,
#    'forcing_4co2': 8.60195313357141,
#    'stochastic_run': False,
#    'sigma_eta': 0.692177568083074,
#    'sigma_xi': 0.702132491057823,
#    'gamma_autocorrelation': 4.80772174825144,
#    'timescales': array([  2.01808629,  27.30202677, 488.52085974]),
#    'response_coefficients': array([0.35110343, 0.42403279, 0.01205379]),
#    'ecs': 3.225231389145626,
#    'tcr': 2.509711128432663}},
#  'CNRM-CM6-1-HR': {'r1i1p1f2': {'ocean_heat_capacity': array([  5.4691211 ,  13.25120584, 105.88971749]),
#    'ocean_heat_transfer': array([1.11016086, 1.61573987, 0.54283182]),
#    'deep_ocean_efficacy': 0.565725333756195,
#    'forcing_4co2': 8.24627266370149,
#    'stochastic_run': False,
#    'sigma_eta': 0.513096067735878,
#    'sigma_xi': 0.592525735216935,
#    'gamma_autocorrelation': 3.50874892560624,
#    'timescales': array([  1.72093253,  15.58456566, 293.86342416]),
#    'response_coefficients': array([0.26447537, 0.44431615, 0.19197884]),
#    'ecs': 3.537985159372933,
#    'tcr': 2.4550337140769103}},
#  'CNRM-ESM2-1': {'r1i1p1f2': {'ocean_heat_capacity': array([  4.07131447,   6.98021824, 100.23643641]),
#    'ocean_heat_transfer': array([0.63448381, 2.65123022, 0.69380362]),
#    'deep_ocean_efficacy': 0.825997165041863,
#    'forcing_4co2': 5.63966830787197,
#    'stochastic_run': False,
#    'sigma_eta': 0.843202540602261,
#    'sigma_xi': 0.568204265865447,
#    'gamma_autocorrelation': 3.78362020552353,
#    'timescales': array([  0.8612795 ,   8.95581329, 316.4284916 ]),
#    'response_coefficients': array([0.14038258, 0.71973584, 0.71596593]),
#    'ecs': 4.2336723800542755,
#    'tcr': 2.2543105841015327},
#   'r3i1p1f2': {'ocean_heat_capacity': array([ 3.48859882,  6.38490241, 99.43651901]),
#    'ocean_heat_transfer': array([0.66615671, 3.57971215, 0.69781821]),
#    'deep_ocean_efficacy': 0.896742725230145,
#    'forcing_4co2': 5.95757435174292,
#    'stochastic_run': False,
#    'sigma_eta': 1.91569944816319,
#    'sigma_xi': 0.574054090448029,
#    'gamma_autocorrelation': 26.2980281166536,
#    'timescales': array([  0.57266108,   7.50269217, 309.79157222]),
#    'response_coefficients': array([0.11040327, 0.68714873, 0.70359628]),
#    'ecs': 4.259683106234149,
#    'tcr': 2.2591371760370107}},
#  'CanESM5': {'r1i1p1f1': {'ocean_heat_capacity': array([ 3.77880871,  9.79628881, 75.96860557]),
#    'ocean_heat_transfer': array([0.61304959, 2.07928869, 0.6179695 ]),
#    'deep_ocean_efficacy': 0.93519958532787,
#    'forcing_4co2': 6.92177501762997,
#    'stochastic_run': False,
#    'sigma_eta': 0.572201380172173,
#    'sigma_xi': 0.479149398549552,
#    'gamma_autocorrelation': 2.82305865552295,
#    'timescales': array([  1.11264204,  11.15749693, 287.5748886 ]),
#    'response_coefficients': array([0.22696815, 0.64725952, 0.75696174]),
#    'ecs': 5.377817978179283,
#    'tcr': 2.8084012799873372},
#   'r1i1p2f1': {'ocean_heat_capacity': array([ 3.60889269, 10.88432547, 70.14913088]),
#    'ocean_heat_transfer': array([0.62758713, 2.45486017, 0.62008856]),
#    'deep_ocean_efficacy': 1.15776538302692,
#    'forcing_4co2': 7.47074196548227,
#    'stochastic_run': False,
#    'sigma_eta': 0.417481876691909,
#    'sigma_xi': 0.479755267878344,
#    'gamma_autocorrelation': 2.51143941345753,
#    'timescales': array([  0.9477156 ,  10.43095291, 291.77042257]),
#    'response_coefficients': array([0.20782466, 0.57392522, 0.81165438]),
#    'ecs': 5.669880933261653,
#    'tcr': 2.7851567710705014}},
#  'E3SM-1-0': {'r1i1p1f1': {'ocean_heat_capacity': array([ 3.67833854,  9.6262782 , 42.42703496]),
#    'ocean_heat_transfer': array([0.58086435, 2.37986856, 0.37426844]),
#    'deep_ocean_efficacy': 1.57356578948367,
#    'forcing_4co2': 7.11344278255743,
#    'stochastic_run': False,
#    'sigma_eta': 0.918048348765317,
#    'sigma_xi': 0.614842838459725,
#    'gamma_autocorrelation': 3.14318525791325,
#    'timescales': array([  0.97322655,  10.99595192, 271.32831272]),
#    'response_coefficients': array([0.20198103, 0.67299805, 0.84659326]),
#    'ecs': 5.832964708928279,
#    'tcr': 2.9343399100905425}},
#  'FGOALS-g3': {'r1i1p1f1': {'ocean_heat_capacity': array([ 4.23178497,  8.1559701 , 90.57676616]),
#    'ocean_heat_transfer': array([1.26096056, 2.67171538, 1.00144013]),
#    'deep_ocean_efficacy': 1.27388897880196,
#    'forcing_4co2': 7.68519153799384,
#    'stochastic_run': False,
#    'sigma_eta': 0.23012580172404,
#    'sigma_xi': 0.449317674819603,
#    'gamma_autocorrelation': 1.07880964648931,
#    'timescales': array([  0.82412225,   4.83904091, 232.35306819]),
#    'response_coefficients': array([0.14003273, 0.31420532, 0.33880817]),
#    'ecs': 2.9029357429435416,
#    'tcr': 1.7454166813739977}},
#  'GISS-E2-1-G': {'r102i1p1f1': {'ocean_heat_capacity': array([  3.2931074 ,  12.20439246, 161.32424595]),
#    'ocean_heat_transfer': array([1.8109177 , 2.26590861, 1.19340124]),
#    'deep_ocean_efficacy': 1.1145725437581,
#    'forcing_4co2': 9.47744120518306,
#    'stochastic_run': False,
#    'sigma_eta': 0.488319007970461,
#    'sigma_xi': 0.745975495529436,
#    'gamma_autocorrelation': 2.25030209691627,
#    'timescales': array([  0.73628206,   5.59439405, 321.43772468]),
#    'response_coefficients': array([0.20086094, 0.16947898, 0.18186629]),
#    'ecs': 2.492737881453337,
#    'tcr': 1.6836094654420473},
#   'r1i1p1f1': {'ocean_heat_capacity': array([  3.32765983,   8.98389571, 159.69494905]),
#    'ocean_heat_transfer': array([1.30302669, 1.85309552, 1.20375655]),
#    'deep_ocean_efficacy': 0.944535956018539,
#    'forcing_4co2': 7.17185409026478,
#    'stochastic_run': False,
#    'sigma_eta': 0.555859091152428,
#    'sigma_xi': 0.605959330369628,
#    'gamma_autocorrelation': 2.92056816960277,
#    'timescales': array([  0.91023365,   5.34081111, 337.86633369]),
#    'response_coefficients': array([0.22861764, 0.25913609, 0.27969026]),
#    'ecs': 2.6215754524261183,
#    'tcr': 1.6801454609795394},
#   'r1i1p3f1': {'ocean_heat_capacity': array([  4.13673938,  12.09131653, 186.70910217]),
#    'ocean_heat_transfer': array([1.42433312, 2.60326461, 1.04810748]),
#    'deep_ocean_efficacy': 1.15466901552805,
#    'forcing_4co2': 7.76786235469861,
#    'stochastic_run': False,
#    'sigma_eta': 0.380869047103412,
#    'sigma_xi': 0.919417435308347,
#    'gamma_autocorrelation': 1.68295836230887,
#    'timescales': array([  0.87846295,   6.49802824, 420.97518001]),
#    'response_coefficients': array([0.17690728, 0.25809586, 0.26707981]),
#    'ecs': 2.5976113662966354,
#    'tcr': 1.5895529587725967},
#   'r1i1p5f1': {'ocean_heat_capacity': array([  3.18326885,  12.89334008, 193.44857318]),
#    'ocean_heat_transfer': array([1.53283655, 1.79081889, 1.06567872]),
#    'deep_ocean_efficacy': 0.949730033755278,
#    'forcing_4co2': 7.97262147569649,
#    'stochastic_run': False,
#    'sigma_eta': 0.42370152660183,
#    'sigma_xi': 0.825314192983639,
#    'gamma_autocorrelation': 2.15403018477418,
#    'timescales': array([  0.88512859,   7.4181211 , 413.36165716]),
#    'response_coefficients': array([0.25417031, 0.19656763, 0.20164734]),
#    'ecs': 2.477362307653879,
#    'tcr': 1.6809277460208087}},
#  'GISS-E2-1-H': {'r1i1p1f1': {'ocean_heat_capacity': array([ 2.24230388, 11.36871985, 73.22808348]),
#    'ocean_heat_transfer': array([1.02663741, 2.38772212, 0.83468411]),
#    'deep_ocean_efficacy': 0.973850127765011,
#    'forcing_4co2': 6.52056592577495,
#    'stochastic_run': False,
#    'sigma_eta': 1.97756475903138,
#    'sigma_xi': 0.491943107576315,
#    'gamma_autocorrelation': 27.0171020207035,
#    'timescales': array([  0.5943875 ,   7.80418012, 196.68160179]),
#    'response_coefficients': array([0.2379364 , 0.34068509, 0.39543225]),
#    'ecs': 3.0251884525725115,
#    'tcr': 1.8661704788241933},
#   'r1i1p3f1': {'ocean_heat_capacity': array([  4.32953767,  26.31392204, 327.46978074]),
#    'ocean_heat_transfer': array([1.52494394, 1.23402467, 0.32873857]),
#    'deep_ocean_efficacy': 0.206813262422408,
#    'forcing_4co2': 7.8546075751831,
#    'stochastic_run': False,
#    'sigma_eta': 0.478934994289842,
#    'sigma_xi': 0.777626225653503,
#    'gamma_autocorrelation': 2.67044817746255,
#    'timescales': array([   1.51706608,   36.16604897, 1099.16879362]),
#    'response_coefficients': array([0.33823626, 0.28901761, 0.02850794]),
#    'ecs': 2.45332362531252,
#    'tcr': 1.84285242642054}},
#  'GISS-E2-2-G': {'r1i1p1f1': {'ocean_heat_capacity': array([  4.02472762,  11.22278778, 261.33563114]),
#    'ocean_heat_transfer': array([2.22425355, 1.94523717, 0.58123096]),
#    'deep_ocean_efficacy': 0.16874299195582,
#    'forcing_4co2': 8.4727580078433,
#    'stochastic_run': False,
#    'sigma_eta': 0.546814136352882,
#    'sigma_xi': 0.599790795702886,
#    'gamma_autocorrelation': 2.18552097722105,
#    'timescales': array([  0.88902323,  10.70627185, 493.14984993]),
#    'response_coefficients': array([0.20186273, 0.22873143, 0.01899487]),
#    'ecs': 1.814365330456385,
#    'tcr': 1.5908244523762534}},
#  'HadGEM3-GC31-LL': {'r1i1p1f3': {'ocean_heat_capacity': array([ 3.82003306,  8.86062322, 66.05192503]),
#    'ocean_heat_transfer': array([0.63038091, 3.14919488, 0.64494935]),
#    'deep_ocean_efficacy': 1.21795095190017,
#    'forcing_4co2': 7.45443344404946,
#    'stochastic_run': False,
#    'sigma_eta': 0.446501649067072,
#    'sigma_xi': 0.617731091711553,
#    'gamma_autocorrelation': 2.93774731293286,
#    'timescales': array([  0.75585036,   8.5827883 , 269.16863199]),
#    'response_coefficients': array([0.14337769, 0.59156164, 0.85140313]),
#    'ecs': 5.6324302018994645,
#    'tcr': 2.7047285657158455}},
#  'HadGEM3-GC31-MM': {'r1i1p1f3': {'ocean_heat_capacity': array([ 3.91591825, 12.74101636, 64.44362675]),
#    'ocean_heat_transfer': array([0.68974294, 2.51101187, 0.67163127]),
#    'deep_ocean_efficacy': 1.10315315832446,
#    'forcing_4co2': 7.58160948030469,
#    'stochastic_run': False,
#    'sigma_eta': 0.451502567435,
#    'sigma_xi': 0.514735293089364,
#    'gamma_autocorrelation': 2.21436107149992,
#    'timescales': array([  1.01050787,  11.19432246, 244.3504898 ]),
#    'response_coefficients': array([0.20896945, 0.51025466, 0.73059138]),
#    'ecs': 5.235502518409598,
#    'tcr': 2.6335028499920123}},
#  'MIROC-ES2L': {'r1i1p1f2': {'ocean_heat_capacity': array([  4.31764089,  14.51652269, 391.50822672]),
#    'ocean_heat_transfer': array([2.15639625, 1.75738598, 0.58626557]),
#    'deep_ocean_efficacy': 0.195402759512074,
#    'forcing_4co2': 9.0982613450674,
#    'stochastic_run': False,
#    'sigma_eta': 0.683384554817314,
#    'sigma_xi': 0.910880418425589,
#    'gamma_autocorrelation': 1.77439764609673,
#    'timescales': array([  1.03586648,  14.24463686, 748.52228066]),
#    'response_coefficients': array([0.22412832, 0.21665128, 0.02295706]),
#    'ecs': 2.0096205728978003,
#    'tcr': 1.7096398175777556}},
#  'MIROC6': {'r1i1p1f1': {'ocean_heat_capacity': array([  4.11067654,  30.05806814, 332.33341946]),
#    'ocean_heat_transfer': array([2.0315819 , 1.04725401, 0.53732622]),
#    'deep_ocean_efficacy': 0.263217073227109,
#    'forcing_4co2': 8.65392453995481,
#    'stochastic_run': False,
#    'sigma_eta': 0.700456280933403,
#    'sigma_xi': 0.851583705091037,
#    'gamma_autocorrelation': 1.78006025608583,
#    'timescales': array([  1.31357053,  36.31542796, 752.97303519]),
#    'response_coefficients': array([0.31419678, 0.14650216, 0.03152832]),
#    'ecs': 2.0289110047143795,
#    'tcr': 1.6117919724595198}},
#  'MPI-ESM1-2-HR': {'r1i1p1f1': {'ocean_heat_capacity': array([ 5.34217409, 29.95208761, 62.29010106]),
#    'ocean_heat_transfer': array([1.11042939, 1.47648579, 1.08800609]),
#    'deep_ocean_efficacy': 1.6791176220264,
#    'forcing_4co2': 7.59191159157924,
#    'stochastic_run': False,
#    'sigma_eta': 0.506857585605866,
#    'sigma_xi': 0.446459734533372,
#    'gamma_autocorrelation': 2.35461193110828,
#    'timescales': array([  1.93106726,  11.07117159, 261.34947954]),
#    'response_coefficients': array([0.33369928, 0.14121811, 0.42563515]),
#    'ecs': 3.2564500684136584,
#    'tcr': 1.7909191784843537}},
#  'MPI-ESM1-2-LR': {'r1i1p1f1': {'ocean_heat_capacity': array([  7.68504439,  40.37681842, 240.89746238]),
#    'ocean_heat_transfer': array([2.02620222, 0.8998633 , 0.30769474]),
#    'deep_ocean_efficacy': 0.188848227355158,
#    'forcing_4co2': 10.5957812291787,
#    'stochastic_run': False,
#    'sigma_eta': 0.43014058296196,
#    'sigma_xi': 0.986915849244127,
#    'gamma_autocorrelation': 1.64327982352783,
#    'timescales': array([  2.57789319,  59.96181946, 861.96887298]),
#    'response_coefficients': array([0.32896998, 0.14951179, 0.01505238]),
#    'ecs': 2.49077457700573,
#    'tcr': 1.9101093929257829}},
#  'MRI-ESM2-0': {'r10i1p1f1': {'ocean_heat_capacity': array([ 2.97900427,  9.14687929, 99.59691938]),
#    'ocean_heat_transfer': array([0.75189587, 2.27352058, 1.04085667]),
#    'deep_ocean_efficacy': 0.788418511825479,
#    'forcing_4co2': 4.9772796849414,
#    'stochastic_run': False,
#    'sigma_eta': 1.03559498975037,
#    'sigma_xi': 0.359860135094619,
#    'gamma_autocorrelation': 1.83300475122777,
#    'timescales': array([  0.81381411,   7.60664535, 246.39056472]),
#    'response_coefficients': array([0.22034912, 0.47421956, 0.63540272]),
#    'ecs': 3.1529608121110306,
#    'tcr': 1.7119766782879988},
#   'r13i1p1f1': {'ocean_heat_capacity': array([ 2.99132354,  8.05696908, 99.88117652]),
#    'ocean_heat_transfer': array([0.74749683, 2.19011251, 0.99325308]),
#    'deep_ocean_efficacy': 0.634963826071758,
#    'forcing_4co2': 4.65587271277396,
#    'stochastic_run': False,
#    'sigma_eta': 1.3248530507852,
#    'sigma_xi': 0.248797560660394,
#    'gamma_autocorrelation': 2.0134769887987,
#    'timescales': array([  0.82447768,   8.01668915, 223.97991792]),
#    'response_coefficients': array([0.21738474, 0.54570157, 0.57471201]),
#    'ecs': 2.966715979492671,
#    'tcr': 1.726427084625378},
#   'r1i1p1f1': {'ocean_heat_capacity': array([ 4.0236701 , 10.32077013, 94.06787447]),
#    'ocean_heat_transfer': array([1.04965949, 2.75348616, 1.20256025]),
#    'deep_ocean_efficacy': 1.26213544147637,
#    'forcing_4co2': 7.15917281695671,
#    'stochastic_run': False,
#    'sigma_eta': 1.05049333459864,
#    'sigma_xi': 0.486520129559173,
#    'gamma_autocorrelation': 3.58769129134887,
#    'timescales': array([  0.84527697,   5.41376694, 245.60603391]),
#    'response_coefficients': array([0.16032738, 0.30794931, 0.48441321]),
#    'ecs': 3.248617930045614,
#    'tcr': 1.7221439059334833},
#   'r1i2p1f1': {'ocean_heat_capacity': array([  5.13604304,  10.42982896, 105.80795014]),
#    'ocean_heat_transfer': array([1.34584232, 3.8043474 , 1.04338956]),
#    'deep_ocean_efficacy': 1.48316638311647,
#    'forcing_4co2': 8.86412397132535,
#    'stochastic_run': False,
#    'sigma_eta': 0.734783575964919,
#    'sigma_xi': 0.662928398856842,
#    'gamma_autocorrelation': 1.6729977333648,
#    'timescales': array([  0.75029147,   5.28560032, 267.53399644]),
#    'response_coefficients': array([0.10408152, 0.28897877, 0.3499688 ]),
#    'ecs': 3.1370819877986653,
#    'tcr': 1.7389024635492123},
#   'r4i1p1f1': {'ocean_heat_capacity': array([ 4.34641373, 10.55814576, 97.27610378]),
#    'ocean_heat_transfer': array([0.97384105, 2.12528729, 1.19809847]),
#    'deep_ocean_efficacy': 1.05118214630619,
#    'forcing_4co2': 6.43696728048104,
#    'stochastic_run': False,
#    'sigma_eta': 0.88744156381239,
#    'sigma_xi': 0.523897529646629,
#    'gamma_autocorrelation': 3.0651991680908,
#    'timescales': array([  1.1270865 ,   6.46691504, 246.98595027]),
#    'response_coefficients': array([0.19811011, 0.33833115, 0.49042037]),
#    'ecs': 3.1483097531934034,
#    'tcr': 1.7320164589811335},
#   'r7i1p1f1': {'ocean_heat_capacity': array([  3.23507448,  10.67735684, 100.00836551]),
#    'ocean_heat_transfer': array([0.8393753 , 2.26361674, 1.03056007]),
#    'deep_ocean_efficacy': 0.876485868887357,
#    'forcing_4co2': 5.53341963922204,
#    'stochastic_run': False,
#    'sigma_eta': 0.862150735637598,
#    'sigma_xi': 0.411838707423546,
#    'gamma_autocorrelation': 2.01128445862497,
#    'timescales': array([  0.88024594,   7.93202485, 252.67593461]),
#    'response_coefficients': array([0.22467782, 0.40979664, 0.55688773]),
#    'ecs': 3.139942172554472,
#    'tcr': 1.7267100846375294}},
#  'NorCPM1': {'r1i1p1f1': {'ocean_heat_capacity': array([ 6.50127123, 16.47901253, 91.37279523]),
#    'ocean_heat_transfer': array([1.13306878, 2.4141953 , 1.21382987]),
#    'deep_ocean_efficacy': 1.58424351521472,
#    'forcing_4co2': 7.79531063988835,
#    'stochastic_run': False,
#    'sigma_eta': 0.493369736136213,
#    'sigma_xi': 0.570571171701995,
#    'gamma_autocorrelation': 1.85111716233926,
#    'timescales': array([  1.4757191 ,   7.09632331, 281.5287776 ]),
#    'response_coefficients': array([0.17177249, 0.25400867, 0.4567778 ]),
#    'ecs': 3.2768863635998233,
#    'tcr': 1.6648566076107483}},
#  'SAM0-UNICON': {'r1i1p1f1': {'ocean_heat_capacity': array([  4.58997223,   6.23947732, 109.80559208]),
#    'ocean_heat_transfer': array([1.03423517, 2.61922911, 1.02089967]),
#    'deep_ocean_efficacy': 1.23398288721619,
#    'forcing_4co2': 8.25615952011699,
#    'stochastic_run': False,
#    'sigma_eta': 0.797980779401583,
#    'sigma_xi': 0.635521988107223,
#    'gamma_autocorrelation': 2.37484031486553,
#    'timescales': array([  0.82877174,   4.60856835, 297.71855605]),
#    'response_coefficients': array([0.10591024, 0.40810373, 0.45288411]),
#    'ecs': 3.8022704179103837,
#    'tcr': 2.103213993344576}}}

# %%
# reconstruct a data table and save
df_out = pd.DataFrame(columns=['model', 'run', 'ecs', 'tcr', 'tau1', 'tau2', 'tau3', 'q1', 'q2', 'q3'])

#values_to_add = {'A': 1, 'B': 2}
#row_to_add = pd.Series(values_to_add, name='x')

#df = df.append(row_to_add)

count = 0
for model in models:
    for run in df.loc[df['model']==model, 'run']:
        values_to_add = {
            'model': model,
            'run': run,
            'ecs': params[model][run]['ecs'],
            'tcr': params[model][run]['tcr'],
            'tau1': params[model][run]['timescales'][0],
            'tau2': params[model][run]['timescales'][1],
            'tau3': params[model][run]['timescales'][2],
            'q1': params[model][run]['response_coefficients'][0],
            'q2': params[model][run]['response_coefficients'][1],
            'q3': params[model][run]['response_coefficients'][2],
        }
        row_to_add = pd.Series(values_to_add, name=count)
        df_out = df_out.append(row_to_add)
        count = count + 1

# %%
df_out
# Out:
#               model         run       ecs       tcr      tau1       tau2  \
# 0        ACCESS-CM2    r1i1p1f1  5.122596  2.345884  0.634562   7.759539
# 1     ACCESS-ESM1-5    r1i1p1f1  4.479672  1.897580  0.836798   6.439241
# 2     AWI-CM-1-1-MR    r1i1p1f1  3.187020  2.040492  1.091259   6.330669
# 3       BCC-CSM2-MR    r1i1p1f1  3.170393  1.760652  0.985343   5.805754
# 4          BCC-ESM1    r1i1p1f1  3.355253  1.826979  2.211158  14.723659
# 5       CAMS-CSM1-0    r1i1p1f1  2.234807  1.649204  0.392397   5.187294
# 6       CAMS-CSM1-0    r2i1p1f1  2.226454  1.645464  0.853624   5.233147
# 7         CESM2-FV2    r1i1p1f1  6.370097  2.148443  0.530880   4.369134
# 8       CESM2-WACCM    r1i1p1f1  5.282444  2.214296  0.328475   4.876315
# 9   CESM2-WACCM-FV2    r1i1p1f1  5.594945  2.063313  0.620994   6.503055
# 10     CMCC-CM2-SR5    r1i1p1f1  2.766888  2.199081  1.541374  28.763710
# 11       CNRM-CM6-1    r1i1p1f2  3.225231  2.509711  2.018086  27.302027
# 12    CNRM-CM6-1-HR    r1i1p1f2  3.537985  2.455034  1.720933  15.584566
# 13      CNRM-ESM2-1    r1i1p1f2  4.233672  2.254311  0.861280   8.955813
# 14      CNRM-ESM2-1    r3i1p1f2  4.259683  2.259137  0.572661   7.502692
# 15          CanESM5    r1i1p1f1  5.377818  2.808401  1.112642  11.157497
# 16          CanESM5    r1i1p2f1  5.669881  2.785157  0.947716  10.430953
# 17         E3SM-1-0    r1i1p1f1  5.832965  2.934340  0.973227  10.995952
# 18        FGOALS-g3    r1i1p1f1  2.902936  1.745417  0.824122   4.839041
# 19      GISS-E2-1-G  r102i1p1f1  2.492738  1.683609  0.736282   5.594394
# 20      GISS-E2-1-G    r1i1p1f1  2.621575  1.680145  0.910234   5.340811
# 21      GISS-E2-1-G    r1i1p3f1  2.597611  1.589553  0.878463   6.498028
# 22      GISS-E2-1-G    r1i1p5f1  2.477362  1.680928  0.885129   7.418121
# 23      GISS-E2-1-H    r1i1p1f1  3.025188  1.866170  0.594387   7.804180
# 24      GISS-E2-1-H    r1i1p3f1  2.453324  1.842852  1.517066  36.166049
# 25      GISS-E2-2-G    r1i1p1f1  1.814365  1.590824  0.889023  10.706272
# 26  HadGEM3-GC31-LL    r1i1p1f3  5.632430  2.704729  0.755850   8.582788
# 27  HadGEM3-GC31-MM    r1i1p1f3  5.235503  2.633503  1.010508  11.194322
# 28       MIROC-ES2L    r1i1p1f2  2.009621  1.709640  1.035866  14.244637
# 29           MIROC6    r1i1p1f1  2.028911  1.611792  1.313571  36.315428
# 30    MPI-ESM1-2-HR    r1i1p1f1  3.256450  1.790919  1.931067  11.071172
# 31    MPI-ESM1-2-LR    r1i1p1f1  2.490775  1.910109  2.577893  59.961819
# 32       MRI-ESM2-0   r10i1p1f1  3.152961  1.711977  0.813814   7.606645
# 33       MRI-ESM2-0   r13i1p1f1  2.966716  1.726427  0.824478   8.016689
# 34       MRI-ESM2-0    r1i1p1f1  3.248618  1.722144  0.845277   5.413767
# 35       MRI-ESM2-0    r1i2p1f1  3.137082  1.738902  0.750291   5.285600
# 36       MRI-ESM2-0    r4i1p1f1  3.148310  1.732016  1.127086   6.466915
# 37       MRI-ESM2-0    r7i1p1f1  3.139942  1.726710  0.880246   7.932025
# 38          NorCPM1    r1i1p1f1  3.276886  1.664857  1.475719   7.096323
# 39      SAM0-UNICON    r1i1p1f1  3.802270  2.103214  0.828772   4.608568
#
#            tau3        q1        q2        q3
# 0    318.551194  0.130658  0.494845  0.793884
# 1    341.731000  0.175808  0.412565  0.910532
# 2    165.337532  0.203445  0.307051  0.334338
# 3    210.750951  0.193863  0.228822  0.408327
# 4    340.718137  0.370248  0.324109  0.527092
# 5    139.272645  0.108380  0.273176  0.150579
# 6    133.548573  0.121871  0.259847  0.151655
# 7    416.729061  0.086223  0.448250  1.260619
# 8    325.545862  0.051597  0.481809  0.863547
# 9    457.211395  0.132048  0.485243  1.158078
# 10  1090.225657  0.338793  0.358883  0.000843
# 11   488.520860  0.351103  0.424033  0.012054
# 12   293.863424  0.264475  0.444316  0.191979
# 13   316.428492  0.140383  0.719736  0.715966
# 14   309.791572  0.110403  0.687149  0.703596
# 15   287.574889  0.226968  0.647260  0.756962
# 16   291.770423  0.207825  0.573925  0.811654
# 17   271.328313  0.201981  0.672998  0.846593
# 18   232.353068  0.140033  0.314205  0.338808
# 19   321.437725  0.200861  0.169479  0.181866
# 20   337.866334  0.228618  0.259136  0.279690
# 21   420.975180  0.176907  0.258096  0.267080
# 22   413.361657  0.254170  0.196568  0.201647
# 23   196.681602  0.237936  0.340685  0.395432
# 24  1099.168794  0.338236  0.289018  0.028508
# 25   493.149850  0.201863  0.228731  0.018995
# 26   269.168632  0.143378  0.591562  0.851403
# 27   244.350490  0.208969  0.510255  0.730591
# 28   748.522281  0.224128  0.216651  0.022957
# 29   752.973035  0.314197  0.146502  0.031528
# 30   261.349480  0.333699  0.141218  0.425635
# 31   861.968873  0.328970  0.149512  0.015052
# 32   246.390565  0.220349  0.474220  0.635403
# 33   223.979918  0.217385  0.545702  0.574712
# 34   245.606034  0.160327  0.307949  0.484413
# 35   267.533996  0.104082  0.288979  0.349969
# 36   246.985950  0.198110  0.338331  0.490420
# 37   252.675935  0.224678  0.409797  0.556888
# 38   281.528778  0.171772  0.254009  0.456778
# 39   297.718556  0.105910  0.408104  0.452884

# %%
df_out.to_csv(os.path.join("..", "data", "calibration", "4xCO2_impulse_response.csv"))
